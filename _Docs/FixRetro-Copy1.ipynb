# %%
import boto3
import os 
import sys

s3 = boto3.client('s3',aws_access_key_id='AKIAJKV6HI4YIS35FTVA',aws_secret_access_key='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')
mm = 'storage.xspaceapp.com'
os.getcwd()
# Out:
# '/mnt/c/xs_RnD/xspace-webapp-v2/_Docs'

# %%
def updir(bucket, destination):

    client = boto3.client('s3',aws_access_key_id='AKIAJKV6HI4YIS35FTVA',aws_secret_access_key='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')
    local_directory = '/mnt/c/xs_RnD/xspace-webapp-v2/_Docs/safe'

    # enumerate local files recursively
    for root, dirs, files in os.walk(local_directory):

      for filename in files:

        # construct the full local path
        local_path = os.path.join(root, filename)

        # construct the full Dropbox path
        relative_path = os.path.relpath(local_path, local_directory)
        s3_path = os.path.join(destination, relative_path)

        # relative_path = os.path.relpath(os.path.join(root, filename))

        print('Searching "%s" in "%s"' % (s3_path, bucket))
        try:
            client.head_object(Bucket=bucket, Key=s3_path)
            print("Path found on S3! Skipping %s..." % s3_path)

            # try:
                # client.delete_object(Bucket=bucket, Key=s3_path)
            # except:
                # print "Unable to delete %s..." % s3_path
        except:
            print("Uploading %s..." % s3_path)
            if local_path.endswith('.html'):
                client.upload_file(local_path, bucket, s3_path, ExtraArgs={'ContentType': "text/html", 'ACL': "public-read"})
            elif local_path.endswith('.css'):
                client.upload_file(local_path, bucket, s3_path, ExtraArgs={'ContentType': "text/css", 'ACL': "public-read"})
            elif local_path.endswith('.svg'):
                client.upload_file(local_path, bucket, s3_path, ExtraArgs={'ContentType': "images/svg+xml", 'ACL': "public-read"})
            elif local_path.endswith('.png'):
                client.upload_file(local_path, bucket, s3_path, ExtraArgs={'ContentType': "images/png", 'ACL': "public-read"})
            elif local_path.endswith('.js'):
                client.upload_file(local_path, bucket, s3_path, ExtraArgs={'ContentType': "application/javascript", 'ACL': "public-read"})
            else:
                client.upload_file(local_path, bucket, s3_path)

# %%
prods = []
for i in range(77, 90):
    prods.append(str(i))
    
for i in range(1425, 1551):
    prods.append(str(i))

# %%
len(prods)
# Out:
# 139

# %%
def psls(ls):
    for i in ls:
        #This cell rus with the 360 folders without preix space like such ie; /product/1425/wcgcvapenu/360/61194203200/360/
        ba = 'rythnstemq/product/'+i+'/'
        response = s3.list_objects_v2(
            Bucket=mm,
            Prefix=ba,
        )

        if response['KeyCount'] > 1:
            for obj in response['Contents']:
                key = obj['Key']
                if key.endswith('.html'):
                    link = key.split('/')
                    asss = link.pop()
                    if asss.startswith('PVC'):
                        passon = '/'.join(link)+'/'
                        xox = passon+'imagerotator/'
                        print(xox)
                        checkf = s3.list_objects_v2(
                            Bucket=mm,
                            Prefix=xox,
                        )
                        if checkf['KeyCount'] > 1:
                            print(xox)
                        else:
                            
                            updir(mm, passon)
                        
                else:
                    pass

# %%
pf = ['1443']
prods
# Out:
# ['77',
#  '78',
#  '79',
#  '80',
#  '81',
#  '82',
#  '83',
#  '84',
#  '85',
#  '86',
#  '87',
#  '88',
#  '89',
#  '1425',
#  '1426',
#  '1427',
#  '1428',
#  '1429',
#  '1430',
#  '1431',
#  '1432',
#  '1433',
#  '1434',
#  '1435',
#  '1436',
#  '1437',
#  '1438',
#  '1439',
#  '1440',
#  '1441',
#  '1442',
#  '1443',
#  '1444',
#  '1445',
#  '1446',
#  '1447',
#  '1448',
#  '1449',
#  '1450',
#  '1451',
#  '1452',
#  '1453',
#  '1454',
#  '1455',
#  '1456',
#  '1457',
#  '1458',
#  '1459',
#  '1460',
#  '1461',
#  '1462',
#  '1463',
#  '1464',
#  '1465',
#  '1466',
#  '1467',
#  '1468',
#  '1469',
#  '1470',
#  '1471',
#  '1472',
#  '1473',
#  '1474',
#  '1475',
#  '1476',
#  '1477',
#  '1478',
#  '1479',
#  '1480',
#  '1481',
#  '1482',
#  '1483',
#  '1484',
#  '1485',
#  '1486',
#  '1487',
#  '1488',
#  '1489',
#  '1490',
#  '1491',
#  '1492',
#  '1493',
#  '1494',
#  '1495',
#  '1496',
#  '1497',
#  '1498',
#  '1499',
#  '1500',
#  '1501',
#  '1502',
#  '1503',
#  '1504',
# ...

# %%
psls(prods)
# Out:
# rythnstemq/product/1425/wcgcvapenu/360/PVC 00101/360/imagerotator/
# rythnstemq/product/1425/wcgcvapenu/360/PVC 00101/360/imagerotator/
# rythnstemq/product/1426/kqmdoyjpyn/360/PVC 00103/360/imagerotator/
# rythnstemq/product/1426/kqmdoyjpyn/360/PVC 00103/360/imagerotator/
# rythnstemq/product/1427/mjzbdccycm/360/PVC 00103P/360/imagerotator/
# rythnstemq/product/1427/mjzbdccycm/360/PVC 00103P/360/imagerotator/
# rythnstemq/product/1429/brbgzjtdfo/360/PVC 00103W/360/imagerotator/
# rythnstemq/product/1429/brbgzjtdfo/360/PVC 00103W/360/imagerotator/
# rythnstemq/product/1430/qvwwlzxjfk/360/PVC 00103X/360/imagerotator/
# rythnstemq/product/1430/qvwwlzxjfk/360/PVC 00103X/360/imagerotator/
# rythnstemq/product/1431/viwhqhhzsl/360/PVC 00104/360/imagerotator/
# Searching "rythnstemq/product/1431/viwhqhhzsl/360/PVC 00104/360/imagerotator/html/css/basic.css" in "storage.xspaceapp.com"
# Uploading rythnstemq/product/1431/viwhqhhzsl/360/PVC 00104/360/imagerotator/html/css/basic.css...
# ...
